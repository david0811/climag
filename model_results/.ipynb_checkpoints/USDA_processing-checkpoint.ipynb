# %% [markdown]
# # Processing USDA data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import statsmodels.api as sm

# %matplotlib inline
plt.rcParams.update({'font.size': 24})

# %% [markdown]
# ### USDA: add state trends to county data

# %%
# Load USDA data
usda_county = pd.read_csv("../usda_yields/output/USDA_county_yields.csv").drop_duplicates(subset = ["GEOID", "year"], keep = "first")
usda_state = pd.read_csv("../usda_yields/output/USDA_state_yields.csv")
usda_state = usda_state.rename(columns = {"Value" : "state_Value", "lowess_log_Value" : "lowess_log_state_Value"})

# %%
# Add logs
usda_county["Log_value"] = usda_county.apply(lambda x: np.log(x["Value"]) if x["Value"] > 0.0 else 0.0, axis = 1)

# %%
# Merge
usda_final = pd.merge(usda_county, usda_state.drop(columns = ["state_alpha", "Area", "log_Value"]), on = ["state_fips_code", "year"], how = "inner", copy = False)
usda_final["GEOID"] = usda_final["GEOID"].astype(str).str[:-2].str.zfill(5)

# %%
# Get differences
usda_final["target_Value"] = usda_final["Log_value"] - usda_final["lowess_log_state_Value"]

# %%
# Add log state value
usda_final["log_state_Value"] = usda_final.apply(lambda x: np.log(x["state_Value"]) if x["state_Value"] > 0.0 else 0.0, axis = 1)

# %%
usda_final.head()
# Out:
#    GEOID  year  state_fips_code  county_code  asd_code  Value     area  \
# 0  01001  1950                1            1        40   17.0  29600.0
# 1  01011  1950                1           11        40   11.0  24200.0
# 2  01047  1950                1           47        40   13.0  44200.0
# 3  01051  1950                1           51        40   23.0  38900.0
# 4  01063  1950                1           63        40   16.0  23900.0
#
#    Log_value  state_Value  lowess_log_state_Value  target_Value  \
# 0   2.833213         21.5                3.033747     -0.200534
# 1   2.397895         21.5                3.033747     -0.635852
# 2   2.564949         21.5                3.033747     -0.468798
# 3   3.135494         21.5                3.033747      0.101747
# 4   2.772589         21.5                3.033747     -0.261158
#
#    log_state_Value
# 0         3.068053
# 1         3.068053
# 2         3.068053
# 3         3.068053
# 4         3.068053

# %%
# Testing
fig, ax = plt.subplots(figsize = (15,6))
usda_final.query("GEOID == '01007'").reset_index().plot(x = "year", y = "Log_value", ax = ax, label = "USDA")
usda_final.query("GEOID == '01007'").reset_index().plot(x = "year", y = "lowess_log_state_Value", ax = ax, label = "lowess")
plt.legend()
plt.show()

# %%
# Save
usda_final.query("Value > 0.0").to_csv("./output/USDA_county_yields_w_state_trends.csv", index = False)

# %% [markdown]
# ### USDA: add county trends to county data

# %%
# Load USDA data
usda_county = pd.read_csv("../usda_yields/output/USDA_county_yields.csv").drop_duplicates(subset = ["GEOID", "year"], keep = "first")
usda_county["GEOID"] = usda_county["GEOID"].astype(str)
usda_county.set_index(["GEOID"], inplace= True)

# %%
# Add logs
usda_county["log_Value"] = usda_county.apply(lambda x: np.log(x["Value"]) if x["Value"] > 0.0 else 0.0, axis = 1)

# %%
# Do lowess filter
lowess = sm.nonparametric.lowess
usda_county = usda_county.query("Value > 0.0")
usda_county["lowess_log_Value"] = 0.0

for geoid in usda_county.index.unique(level = "GEOID"):

    data = usda_county.loc[geoid]
    
    if type(data["Value"]) != np.float64:
        lws_filter = lowess(data["log_Value"], data["year"], missing = "drop")
    
        temp = pd.DataFrame(data = {"lowess_log_Value_x" : pd.Series(lws_filter[:,1], index = pd.MultiIndex.from_arrays([[geoid]*len(lws_filter[:,0].astype(int)), lws_filter[:,0].astype(int)]))})
        temp.index.names = ["GEOID", "year"]
        usda_county = pd.merge(usda_county, temp, on = ["GEOID", "year"], how = "outer")
        usda_county = usda_county.fillna(0)
        usda_county["lowess_log_Value"] = usda_county["lowess_log_Value"] + usda_county["lowess_log_Value_x"]
        del usda_county["lowess_log_Value_x"]

# %%
# Get differences
usda_county["target_Value"] = usda_county["log_Value"] - usda_county["lowess_log_Value"]

# %%
usda_county.head()
# Out:
#         year  state_fips_code  county_code  asd_code  Value     area  \
# GEOID
# 100140  1950                1            1        40   17.0  29600.0
# 101140  1950                1           11        40   11.0  24200.0
# 104740  1950                1           47        40   13.0  44200.0
# 105140  1950                1           51        40   23.0  38900.0
# 106340  1950                1           63        40   16.0  23900.0
#
#         log_Value  lowess_log_Value  target_Value
# GEOID
# 100140   2.833213          2.922636     -0.089422
# 101140   2.397895          2.684326     -0.286430
# 104740   2.564949          2.724326     -0.159377
# 105140   3.135494          3.057709      0.077785
# 106340   2.772589          2.724703      0.047885

# %%
# Testing
fig, ax = plt.subplots(figsize = (15,6))
usda_county.query("GEOID == '100140'").reset_index().plot(x = "year", y = "log_Value", ax = ax, label = "USDA")
usda_county.query("GEOID == '100140'").reset_index().plot(x = "year", y = "lowess_log_Value", ax = ax, label = "lowess")
plt.legend()
plt.show()

# %%
# Save
usda_county.query("Value > 0.0").to_csv("./output/USDA_county_yields_w_county_trends.csv", index = False)
