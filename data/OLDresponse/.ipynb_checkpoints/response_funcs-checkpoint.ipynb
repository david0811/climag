# %% [markdown]
# # Store yield response function from the American Climate Prospectus
#
# (https://science.sciencemag.org/content/356/6345/1362.full?ijkey=x3wZ8kcgtomUM&keytype=ref&siteid=sci)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate

import seaborn as sns
sns.set()

# %%
maize_east_alpha = 0.01 * np.array([0.031309186999999995,0.01797380960519212,0.04464456439480787])
maize_east_beta = 0.01 * np.array([-0.61613785,-0.7498515007751361,-0.4824241992248639])

# %%
fig, ax = plt.subplots(1)

ax.set_ylabel("Log(yield)")
ax.set_xlabel("Temp.")

plt.plot(np.linspace(0,10,2), 0 * np.linspace(0,10,2), color = "C0")
plt.plot(np.linspace(10,29,2), (maize_east_alpha[0] * np.linspace(10,29,2)) - (maize_east_alpha[0] * 10), color = "C0")
plt.plot(np.linspace(29,40,2), (maize_east_beta[0] * np.linspace(29,40,2)) - (maize_east_beta[0] * 29) + (maize_east_alpha[0] * 19), color = "C0")

plt.plot(np.linspace(0,10,2), 0 * np.linspace(0,10,2), color = "C3")
plt.plot(np.linspace(10,29,2), (maize_east_alpha[1] * np.linspace(10,29,2)) - (maize_east_alpha[1] * 10), color = "C3")
plt.plot(np.linspace(29,40,2), (maize_east_beta[1] * np.linspace(29,40,2)) - (maize_east_beta[1] * 29) + (maize_east_alpha[1] * 19), color = "C3")

plt.plot(np.linspace(0,10,2), 0 * np.linspace(0,10,2), color = "C3")
plt.plot(np.linspace(10,29,2), (maize_east_alpha[2] * np.linspace(10,29,2)) - (maize_east_alpha[2] * 10), color = "C3")
plt.plot(np.linspace(29,40,2), (maize_east_beta[2] * np.linspace(29,40,2)) - (maize_east_beta[2] * 29) + (maize_east_alpha[2] * 19), color = "C3")

plt.show()

# %%
maize_east_precip = np.array([0.0384615384615,0.0379846926183432,-0.1388760266171904,0.2148454118538768,
0.0769230769231,0.07358587816568048,-0.17267123076288354,0.3198429870942445,
0.115384615385,0.10680355664201184,-0.1900025533973897,0.4036096666814134,
0.153846153846,0.1376377280473373,-0.19946708942411737,0.4747425455187919,
0.192307692308,0.16608839238165682,-0.20443395478575174,0.5366107395490654,
0.230769230769,0.19215554964497045,-0.20664663480100726,0.5909577340909482,
0.269230769231,0.2158391998372781,-0.20714756419873606,0.6388259638732923,
0.307692307692,0.23713934295857989,-0.2066185685256066,0.6808972544427664,
0.346153846154,0.2560559790088757,-0.20553377066642675,0.7176457286841782,
0.384615384615,0.27258910798816577,-0.2042378024448362,0.7494160184211678,
0.423076923077,0.28673872989644966,-0.20298973312474733,0.7764671929176467,
0.461538461538,0.29850484473372785,-0.2019895958033242,0.7989992852707799,
0.5,0.30788745250000005,-0.20139540585863602,0.8171703108586361,
0.538461538462,0.31488655319526626,-0.2013347079087051,0.8311078142992376,
0.576923076923,0.31950214681952666,-0.20191288197256513,0.8409171756116185,
0.615384615385,0.3217342333727811,-0.2032195413237639,0.8466880080693262,
0.653846153846,0.3215828128550296,-0.20533389463395219,0.8484995203440113,
0.692307692308,0.3190478852662722,-0.2083297165960461,0.8464254871285906,
0.730769230769,0.314129450606509,-0.21228047878830592,0.8405393800013239,
0.769230769231,0.3068275088757397,-0.2172651908036562,0.8309202085551355,
0.807692307692,0.2971420600739645,-0.22337556704164896,0.8176596871895779,
0.846153846154,0.28507310420118337,-0.23072524644347425,0.800871454845841,
0.884615384615,0.2706206412573965,-0.2394619113375832,0.7807031938523762,
0.923076923077,0.2537846712426035,-0.24978318182717996,0.757352524312387,
0.961538461538,0.2345651941568049,-0.2619568862702294,0.7310872745838393,
1.0,0.21296221000000007,-0.27634528986806683,0.702269709868067,
1.03846153846,0.18897571877218922,-0.29343037462783106,0.6713818121722095,
1.07692307692,0.16260572047337263,-0.31383247773049155,0.6390439186772368,
1.11538461538,0.1338522151035504,-0.33830760858916503,0.6060120387962658,
1.15384615385,0.10271520266272183,-0.36770302964354873,0.5731334349689924,
1.19230769231,0.06919468315088761,-0.4028553751993807,0.5412447415011559,
1.23076923077,0.033290656568047305,-0.4444411714389148,0.5110224845750094,
1.26923076923,-0.004996877085798657,-0.4928302859814331,0.48283653180983577,
1.30769230769,-0.04566791781065094,-0.5480133603990022,0.4566775247777003,
1.34615384615,-0.08872246560650886,-0.6096408743049416,0.4321959430919239,
1.38461538462,-0.13416052047337268,-0.6771455770782143,0.40882453613146896,
1.42307692308,-0.18198208241124258,-0.7498823290671999,0.3859181642447147,
1.46153846154,-0.23218715142011837,-0.8272337735984588,0.3628594707582221,
1.5,-0.2847757275,-0.9086667223737966,0.3391152673737966])

# %%
maize_east_precip_x = []
maize_east_precip_y = []
for i in range(0,int(len(maize_east_precip)),4):
    maize_east_precip_x.append(maize_east_precip[i])
    maize_east_precip_y.append(maize_east_precip[i+1:i+4])

maize_east_precip_x = np.asarray(maize_east_precip_x)
maize_east_precip_y = np.asarray(maize_east_precip_y)

# %%
np.save("./output/maize_east_precip_x.npy", maize_east_precip_x)
np.save("./output/maize_east_precip_y.npy", maize_east_precip_y)

# %%
maize_east_interp = interpolate.interp1d(maize_east_precip_x, maize_east_precip_y[:,0])

# %%
plt.plot(maize_east_precip_x, maize_east_interp(maize_east_precip_x))

# %%
maize_east_interp(0.62491) + maize_east_alpha[0]*2109.77 + maize_east_beta[0]*99.88
# Out:
# 0.3668500825572557

# %%
fig, ax = plt.subplots(1)

ax.set_ylabel("Log(yield)")
ax.set_xlabel("Precip.")

plt.plot(maize_east_precip_x, maize_east_precip_y[:,0], color = "C0")
plt.plot(maize_east_precip_x, maize_east_precip_y[:,1], color = "C3")
plt.plot(maize_east_precip_x, maize_east_precip_y[:,2], color = "C3")

plt.show()

# %%
maize_west_alpha = 0.01 * np.array([0.026968688416391183,0.018462249849965473,0.03547512698281689])
maize_west_beta = 0.01 * np.array([-0.299402820671972,-0.3619227745565575,-0.2368828667873865])

# %%
maize_west_beta[0]
# Out:
# -0.00299402820671972

# %%
fig, ax = plt.subplots(1)

ax.set_ylabel("Log(yield)")
ax.set_xlabel("Temp.")

plt.plot(np.linspace(0,10,2), 0 * np.linspace(0,10,2), color = "C0")
plt.plot(np.linspace(10,29,2), (maize_west_alpha[0] * np.linspace(10,29,2)) - (maize_west_alpha[0] * 10), color = "C0")
plt.plot(np.linspace(29,40,2), (maize_west_beta[0] * np.linspace(29,40,2)) - (maize_west_beta[0] * 29) + (maize_west_alpha[0] * 19), color = "C0")

plt.plot(np.linspace(0,10,2), 0 * np.linspace(0,10,2), color = "C3")
plt.plot(np.linspace(10,29,2), (maize_west_alpha[1] * np.linspace(10,29,2)) - (maize_west_alpha[1] * 10), color = "C3")
plt.plot(np.linspace(29,40,2), (maize_west_beta[1] * np.linspace(29,40,2)) - (maize_west_beta[1] * 29) + (maize_west_alpha[1] * 19), color = "C3")

plt.plot(np.linspace(0,10,2), 0 * np.linspace(0,10,2), color = "C3")
plt.plot(np.linspace(10,29,2), (maize_west_alpha[2] * np.linspace(10,29,2)) - (maize_west_alpha[2] * 10), color = "C3")
plt.plot(np.linspace(29,40,2), (maize_west_beta[2] * np.linspace(29,40,2)) - (maize_west_beta[2] * 29) + (maize_west_alpha[2] * 19), color = "C3")

plt.show()

# %%
maize_west_precip = np.array([0.0384615384615,0.026008320695266273,-0.1733069021702594,0.22532354356079193,
0.0769230769231,0.05069795278106509,-0.2278987278455717,0.3292946334077019,
0.115384615385,0.07406889625739645,-0.26308147805050186,0.4112192705652947,
0.153846153846,0.09612115112426035,-0.2884451496557302,0.4806874519042509,
0.192307692308,0.11685471738165681,-0.3077401310323257,0.5414495657956393,
0.230769230769,0.13626959502958577,-0.3229050004783365,0.595444190537508,
0.269230769231,0.15436578406804732,-0.3350985706503762,0.6438301387864708,
0.307692307692,0.17114328449704141,-0.3450792876469331,0.6873658566410159,
0.346153846154,0.18660209631656804,-0.3533753276514667,0.7265795202846028,
0.384615384615,0.20074221952662724,-0.3603713898951864,0.761855828948441,
0.423076923077,0.21356365412721895,-0.3663572538792295,0.7934845621336675,
0.461538461538,0.2250664001183432,-0.3715568921628448,0.8216896923995313,
0.5,0.23525045749999998,-0.37614689530866907,0.846647810308669,
0.538461538462,0.24411582627218936,-0.38026865156501205,0.8685003041093908,
0.576923076923,0.2516625064349112,-0.38403669259848,0.8873617054683025,
0.615384615385,0.25789049798816566,-0.3875445884391082,0.9033255844154395,
0.653846153846,0.2627998009319526,-0.39086922287468967,0.9164688247385948,
0.692307692308,0.26639041526627216,-0.3940739695885632,0.9268548001211075,
0.730769230769,0.2686623409911242,-0.3972111071418133,0.9345357891240617,
0.769230769231,0.2696155781065089,-0.4003237008932305,0.9395548571062482,
0.807692307692,0.269250126612426,-0.4034471123277097,0.9419473655525616,
0.846153846154,0.2675659865088757,-0.40661025480868934,0.9417422278264407,
0.884615384615,0.26456315779585793,-0.40983669054138017,0.938963006133096,
0.923076923077,0.2602416404733726,-0.4131456517429468,0.933628932689692,
0.961538461538,0.25460143454142015,-0.41655306747413956,0.9257559365569799,
1.0,0.24764254,-0.4200726859781456,0.9153577659781456,
1.03846153846,0.23936495684911233,-0.42371740201565,0.9024473157138746,
1.07692307692,0.22976868508875736,-0.4275009326216095,0.8870383027991242,
1.11538461538,0.21885372471893483,-0.43144003802226116,0.8691474874601308,
1.15384615385,0.2066200757396448,-0.4355575646954758,0.8487977161747654,
1.19230769231,0.19306773815088754,-0.4398867049808298,0.8260221812826049,
1.23076923077,0.17819671195266265,-0.4444770343195875,0.8008704582249128,
1.26923076923,0.16200699714497033,-0.44940311280625156,0.7734171070961923,
1.30769230769,0.1444985937278105,-0.4547767165679849,0.7437739040236059,
1.34615384615,0.12567150170118335,-0.4607640418958039,0.7121070452981706,
1.38461538462,0.10552572106508873,-0.4676093203614027,0.6786607624915801,
1.42307692308,0.0840612518195265,-0.4756657360208525,0.6437882396599055,
1.46153846154,0.061278093964496794,-0.4854323672926779,0.6079885552216715,
1.5,0.037176247499999926,-0.497590435203077,0.5719429302030768])

# %%
maize_west_precip_x = []
maize_west_precip_y = []
for i in range(0,int(len(maize_west_precip)),4):
    maize_west_precip_x.append(maize_west_precip[i])
    maize_west_precip_y.append(maize_west_precip[i+1:i+4])

maize_west_precip_x = np.asarray(maize_west_precip_x)
maize_west_precip_y = np.asarray(maize_west_precip_y)

# %%
np.save("./output/maize_west_precip_x.npy", maize_west_precip_x)
np.save("./output/maize_west_precip_y.npy", maize_west_precip_y)

# %%
fig, ax = plt.subplots(1)

ax.set_ylabel("Log(yield)")
ax.set_xlabel("Precip.")

plt.plot(maize_west_precip_x, maize_west_precip_y[:,0], color = "C0")
plt.plot(maize_west_precip_x, maize_west_precip_y[:,1], color = "C3")
plt.plot(maize_west_precip_x, maize_west_precip_y[:,2], color = "C3")

plt.show()
