# %%
import numpy as np
import pandas as pd
from scipy.stats import chisquare
from scipy.stats import rankdata

import geopandas as gp
from shapely.geometry import Point
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib import gridspec
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Avenir'
plt.rcParams['mathtext.rm'] = 'Avenir'
plt.rcParams['mathtext.it'] = 'Avenir:italic'
plt.rcParams['mathtext.bf'] = 'Avenir:bold'
plt.rcParams['font.size'] = 22
plt.rcParams['axes.edgecolor']='#333F4B'
plt.rcParams['axes.linewidth']=0.8
plt.rcParams['xtick.color']='#333F4B'
plt.rcParams['ytick.color']='#333F4B'
plt.rcParams['pdf.fonttype'] = 42

cm_data = np.loadtxt("/Users/davidlafferty/Projects/misc/ScientificColourMaps5/batlow/batlow.txt")
batlow_map = LinearSegmentedColormap.from_list("Batlow", cm_data)

cm_data = np.loadtxt("/Users/davidlafferty/Projects/misc/ScientificColourMaps5/cork/cork.txt")
cork_map = LinearSegmentedColormap.from_list("Cork", cm_data)

cm_data = np.loadtxt("/Users/davidlafferty/Projects/misc/ScientificColourMaps5/berlin/berlin.txt")
berlin_map = LinearSegmentedColormap.from_list("Berlin", cm_data)

cm_data = np.loadtxt("/Users/davidlafferty/Projects/misc/ScientificColourMaps5/lapaz/lapaz.txt")
lapaz_map = LinearSegmentedColormap.from_list("LaPaz", cm_data)

cm_data = np.loadtxt("/Users/davidlafferty/Projects/misc/ScientificColourMaps5/tokyo/tokyo.txt")
tokyo_map = LinearSegmentedColormap.from_list("Tokyo", cm_data)

cm_data = np.loadtxt("/Users/davidlafferty/Projects/misc/ScientificColourMaps5/bamako/bamako.txt")
bamako_map = LinearSegmentedColormap.from_list("Bamako", cm_data)

cm_data = np.loadtxt("/Users/davidlafferty/Projects/misc/ScientificColourMaps5/turku/turku.txt")[::-1]
turku_map = LinearSegmentedColormap.from_list("Turku", cm_data)

# %%
# Import plotting shapefiles
county_shp = gp.read_file('../../data/conus_shp/conus_plot/final/counties_contig_plot.shp')
county_shp["GEOID"] = county_shp["GEOID"].astype(str).str.zfill(5)
county_shp['area'] = county_shp['geometry'].apply(lambda x: x.area)
county_shp = county_shp.query('area > 10e3')

states = gp.read_file('../../data/conus_shp/conus_plot/final/states_contig_plot.shp')
coast = gp.read_file('../../data/conus_shp/conus_plot/final/coast_contig_plot.shp')

# %%
def rankz(obs,ensemble):
    combined=np.vstack((obs[np.newaxis],ensemble))
    ranks=np.apply_along_axis(lambda x: rankdata(x,method='min'),0,combined)
    ties=np.sum(ranks[0]==ranks[1:], axis=0)
    ranks=ranks[0]
    tie=np.unique(ties)
    for i in range(1,len(tie)):
        index=ranks[ties==tie[i]]
        ranks[ties==tie[i]]=[np.random.randint(index[j],index[j]+tie[i]+1,tie[i])[0] for j in range(len(index))]
    return np.histogram(ranks, bins=np.linspace(0.5, combined.shape[0]+0.5, combined.shape[0]+1))

# %%
# Read data
cmip = pd.read_csv("../combine/output/cmip_agvar_all.csv")
cmip["GEOID"] = cmip["GEOID"].astype(str).str.zfill(5)
cmip.set_index(["AgVar","GEOID","Year"], inplace = True)

nex = pd.read_csv("../combine/output/nex_agvar_hist.csv")
nex["GEOID"] = nex["GEOID"].astype(str).str.zfill(5)
nex.set_index(["AgVar","GEOID","Year"], inplace = True)

gmfd = pd.read_csv("../../data/ACI_output/raw/GMFD/agvar_historical_gmfd.csv")
gmfd["GEOID"] = gmfd["GEOID"].astype(str).str.zfill(5)
gmfd.set_index(["GEOID","Year"], inplace = True)

cmipYield = pd.read_csv("../combine/output/cmip_yield_60-05.csv")
cmipYield["GEOID"] = cmipYield["GEOID"].astype(str).str.zfill(5)
cmipYield.set_index(["GEOID","Year"], inplace = True)

nexYield = pd.read_csv("../combine/output/nex_yield_60-05.csv")
nexYield["GEOID"] = nexYield["GEOID"].astype(str).str.zfill(5)
nexYield.set_index(["GEOID","Year"], inplace = True)

# %% [markdown]
# # Rank histogram, national-level

# %% [markdown]
# ### GDD

# %%
# CMIP calc
cmip_ens = cmip.query("AgVar == 'gdd' and Year <= 2005 and Year >= 1956").groupby(["Year"]).mean().drop(columns = ['GMFD','ensemble_mean']).T.values.reshape((21,50,1))
gmfd_obs = gmfd.query("Year <= 2005")['gdd'].groupby(["Year"]).mean().values.reshape((50,1))
cmip_gdd = rankz(gmfd_obs, cmip_ens)

# NEX calc
nex_ens = nex.query("AgVar == 'gdd' and Year <= 2005 and Year >= 1956").groupby(["Year"]).mean().drop(columns = ['GMFD','ensemble_mean']).T.values.reshape((21,50,1))
gmfd_obs = gmfd.query("Year <= 2005")['gdd'].groupby("Year").mean().values.reshape((50,1))
nex_gdd = rankz(gmfd_obs, nex_ens)

# Plot
fig, ax = plt.subplots(2,1, figsize = (7,10), sharex = True)

ax[0].bar(range(1,cmip_ens.shape[0]+2), cmip_gdd[0])
ax[0].arrow(0., 1/22. * 50, 22.5, 0., color="gray", ls = "--")
ax[1].bar(range(1,nex_ens.shape[0]+2), nex_gdd[0])
ax[1].arrow(0., 1/22. * 50, 22.5, 0., color="gray", ls = "--")

ax[0].set_title("CMIP gdd")
ax[1].set_title("NEX gdd")

ax[0].set_xlim([0.5,22.5])

ax[1].set_xlabel("Rank")

ax[0].set_ylabel("Frequency")
ax[1].set_ylabel("Frequency")

plt.tight_layout()
# plt.savefig("./output/figs/gdd_rankHist.png", dpi = 500)
plt.show()

# %% [markdown]
# ### eGDD

# %%
# CMIP calc
cmip_ens = cmip.query("AgVar == 'egdd' and Year <= 2005 and Year >= 1956").groupby(["Year"]).mean().drop(columns = ['GMFD','ensemble_mean']).T.values.reshape((21,50,1))
gmfd_obs = gmfd.query("Year <= 2005")['egdd'].groupby(["Year"]).mean().values.reshape((50,1))
cmip_egdd = rankz(gmfd_obs, cmip_ens)

# NEX calc
nex_ens = nex.query("AgVar == 'egdd' and Year <= 2005 and Year >= 1956").groupby(["Year"]).mean().drop(columns = ['GMFD','ensemble_mean']).T.values.reshape((21,50,1))
gmfd_obs = gmfd.query("Year <= 2005")['egdd'].groupby("Year").mean().values.reshape((50,1))
nex_egdd = rankz(gmfd_obs, nex_ens)

# Plot
fig, ax = plt.subplots(2,1, figsize = (7,10), sharex = True)

ax[0].bar(range(1,cmip_ens.shape[0]+2), cmip_egdd[0])
ax[0].arrow(0., 1/22. * 50, 22.5, 0., color="gray", ls = "--")
ax[1].bar(range(1,nex_ens.shape[0]+2), nex_egdd[0])
ax[1].arrow(0., 1/22. * 50, 22.5, 0., color="gray", ls = "--")

ax[0].set_title("CMIP eGDD")
ax[1].set_title("NEX eGDD")

ax[0].set_xlim([0.5,22.5])

ax[1].set_xlabel("Rank")

ax[0].set_ylabel("Frequency")
ax[1].set_ylabel("Frequency")

plt.tight_layout()
# plt.savefig("./output/figs/egdd_rankHist.png", dpi = 500)
plt.show()

# %% [markdown]
# ### Precip

# %%
# CMIP calc
cmip_ens = cmip.query("AgVar == 'prcp' and Year <= 2005 and Year >= 1956").groupby(["Year"]).mean().drop(columns = ['GMFD','ensemble_mean']).T.values.reshape((21,50,1))
gmfd_obs = gmfd.query("Year <= 2005")['prcp'].groupby(["Year"]).mean().values.reshape((50,1))
cmip_prcp = rankz(gmfd_obs, cmip_ens)

# NEX calc
nex_ens = nex.query("AgVar == 'prcp' and Year <= 2005 and Year >= 1956").groupby(["Year"]).mean().drop(columns = ['GMFD','ensemble_mean']).T.values.reshape((21,50,1))
gmfd_obs = gmfd.query("Year <= 2005")['prcp'].groupby("Year").mean().values.reshape((50,1))
nex_prcp = rankz(gmfd_obs, nex_ens)

# Plot
fig, ax = plt.subplots(2,1, figsize = (7,10), sharex = True)

ax[0].bar(range(1,cmip_ens.shape[0]+2), cmip_prcp[0])
ax[0].arrow(0., 1/22. * 50, 22.5, 0., color="gray", ls = "--")
ax[1].bar(range(1,nex_ens.shape[0]+2), nex_prcp[0])
ax[1].arrow(0., 1/22. * 50, 22.5, 0., color="gray", ls = "--")

ax[0].set_title("CMIP Precip")
ax[1].set_title("NEX Precip")

ax[0].set_xlim([0.5,22.5])

ax[1].set_xlabel("Rank")

ax[0].set_ylabel("Frequency")
ax[1].set_ylabel("Frequency")

plt.tight_layout()
# plt.savefig("./output/figs/prcp_rankHist.png", dpi = 500)
plt.show()

# %% [markdown]
# ### Yields

# %%
# CMIP calc
cmip_ens = cmipYield.query("Year <= 2005 and Year >= 1956").groupby(["Year"]).mean().drop(columns = ['GMFD','ensemble_mean','USDA']).T.values.reshape((21,46,1))
gmfd_obs = cmipYield.query("Year <= 2005")['GMFD'].groupby(["Year"]).mean().values.reshape((46,1))
cmip_prcp = rankz(gmfd_obs, cmip_ens)

# NEX calc
nex_ens = nexYield.query("Year <= 2005 and Year >= 1956").groupby(["Year"]).mean().drop(columns = ['GMFD','ensemble_mean','USDA']).T.values.reshape((21,46,1))
nex_prcp = rankz(gmfd_obs, nex_ens)

# Plot
fig, ax = plt.subplots(2,1, figsize = (7,10), sharex = True)

ax[0].bar(range(1,cmip_ens.shape[0]+2), cmip_prcp[0])
ax[0].arrow(0., 1/22. * 50, 22.5, 0., color="gray", ls = "--")
ax[1].bar(range(1,nex_ens.shape[0]+2), nex_prcp[0])
ax[1].arrow(0., 1/22. * 50, 22.5, 0., color="gray", ls = "--")

ax[0].set_title("CMIP Yield")
ax[1].set_title("NEX Yield")

ax[0].set_xlim([0.5,22.5])

ax[1].set_xlabel("Rank")

ax[0].set_ylabel("Frequency")
ax[1].set_ylabel("Frequency")

plt.tight_layout()
# plt.savefig("./output/figs/prcp_rankHist.png", dpi = 500)
plt.show()

# %% [markdown]
# # Rank histogram, county-level

# %% [markdown]
# ### Yields

# %%
# Get NEX p-values of chi square test of rank-histogram uniformity
pvals = {}

for geoid in nexYield.index.unique(level = "GEOID"):
    string = "GEOID == '" + geoid + "' and Year <= 2005 and Year >= 1960"
    nex_ens = nexYield.query(string).drop(columns = ['GMFD','ensemble_mean','USDA'])
    years = int(nex_ens.size / 21)
    nex_ens = nex_ens.T.to_numpy().reshape((21,years,1))
    gmfd_obs = nexYield.query(string)['GMFD'].to_numpy().reshape((years,1))
    pval = chisquare(rankz(gmfd_obs, nex_ens)[0])[1]

    pvals.update({geoid :  pval})
    
NEXp = pd.DataFrame.from_dict(pvals, orient = 'index', columns = ['NEX_pval'])
NEXp.index.name = 'GEOID'

# %%
# Get CMIP p-values of chi square test of rank-histogram uniformity
pvals = {}

for geoid in nexYield.index.unique(level = "GEOID"):
    string = "GEOID == '" + geoid + "' and Year <= 2005 and Year >= 1960"
    cmip_ens = cmipYield.query(string).drop(columns = ['GMFD','ensemble_mean','USDA'])
    years = int(cmip_ens.size / 21)
    cmip_ens = cmip_ens.T.to_numpy().reshape((21,years,1))
    gmfd_obs = cmipYield.query(string)['GMFD'].to_numpy().reshape((years,1))
    pval = chisquare(rankz(gmfd_obs, cmip_ens)[0])[1]

    pvals.update({geoid :  pval})
    
CMIPp = pd.DataFrame.from_dict(pvals, orient = 'index', columns = ['CMIP_pval'])
CMIPp.index.name = 'GEOID'

# %%
# Plot 
fig, ax = plt.subplots(1,1, figsize=(18, 12))
data = pd.merge(county_shp, NEXp.reset_index(), on=['GEOID'], how='outer', copy=False)
vmin, vmax = 0., 1.,
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
data.dropna().query('NEX_pval < 0.05').plot(column='NEX_pval', ax = ax, cax = cax, legend=True, vmin = vmin, vmax = vmax, cmap = batlow_map)
states.geometry.boundary.plot(ax=ax, linewidth=0.5, edgecolor="black", color=None)
coast.geometry.boundary.plot(ax=ax, linewidth=0.5, edgecolor="black", color=None)
ax.tick_params(labelbottom=False, labelleft=False, color = 'white')
ax.set_title('NEX Yield Rank-Histogram Flatness Test')
# Show
plt.tight_layout()
plt.show()

# %%
# Plot 
fig, ax = plt.subplots(1,1, figsize=(18, 12))
data = pd.merge(county_shp, CMIPp.reset_index(), on=['GEOID'], how='outer', copy=False)
vmin, vmax = 0., 1.,
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
data.dropna().query('CMIP_pval < 0.05').plot(column='CMIP_pval', ax = ax, cax = cax, legend=True, vmin = vmin, vmax = vmax, cmap = batlow_map)
states.geometry.boundary.plot(ax=ax, linewidth=0.5, edgecolor="black", color=None)
coast.geometry.boundary.plot(ax=ax, linewidth=0.5, edgecolor="black", color=None)
ax.tick_params(labelbottom=False, labelleft=False, color = 'white')
ax.set_title('CMIP Yield Rank-Histogram Flatness Test')
# Show
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Ag Vars

# %%
# Get data
nex_pvals = pd.read_csv("../county/output/old/old/nex_pVals.csv")

cmip_pvals = pd.read_csv("../county/output/old/old/cmip_pVals.csv")

pvals = pd.merge(nex_pvals, cmip_pvals, on = ["AgVar", "GEOID"], suffixes = ["_NEX", "_CMIP"])
pvals["GEOID"] = pvals["GEOID"].astype(str).str.zfill(5)
pvals.set_index(["AgVar", "GEOID"], inplace = True)

# %%
# Merge with county shapefile
pvals = pd.merge(county_shp, pvals.reset_index(), on = "GEOID", how = "outer", copy = False)
pvals.set_index(["AgVar", "GEOID"], inplace = True)

# %% [markdown]
# ### Precip

# %%
# CMIP
fig, ax = plt.subplots(1,1, figsize = (18,10))
# divider = make_axes_locatable(ax)
# cax = divider.append_axes("right", size="5%", pad=0.1)
# pvals.query("AgVar == 'prcp'").plot(column = "pVal_CMIP", ax = ax, cax = cax, legend = True, cmap = batlow_map, vmin=0.0, vmax=1.0)
pvals.query("AgVar == 'prcp' and pVal_CMIP < 0.05").plot(color = 'darkgray', ax = ax, legend = 'Unreliable')
pvals.query("AgVar == 'prcp' and pVal_CMIP >= 0.05").plot(color = '#7570b3', ax = ax, legend = 'Reliable')
ax.tick_params(labelbottom=False, labelleft = False)
states.geometry.boundary.plot(ax = ax, linewidth = 0.5, edgecolor = "black", color = None)
coast.geometry.boundary.plot(ax = ax, linewidth = 0.5, edgecolor = "black", color = None)
ax.set_title("CMIP Precipitation")
plt.tight_layout()
plt.savefig('./cmip_prcp.png', dpi=600)

# %%
# NEX
fig, ax = plt.subplots(1,1, figsize = (18,10))
# divider = make_axes_locatable(ax)
# cax = divider.append_axes("right", size="5%", pad=0.1)
# pvals.query("AgVar == 'prcp'").plot(column = "pVal_NEX", ax = ax, cax = cax, legend = True, cmap = batlow_map, vmin=0.0, vmax=1.0)
pvals.query("AgVar == 'prcp' and pVal_NEX < 0.05").plot(color = 'darkgray', ax = ax, legend = False)
pvals.query("AgVar == 'prcp' and pVal_NEX >= 0.05").plot(color = '#7570b3', ax = ax, legend = False)
ax.tick_params(labelbottom=False, labelleft = False)
states.geometry.boundary.plot(ax = ax, linewidth = 0.5, edgecolor = "black", color = None)
coast.geometry.boundary.plot(ax = ax, linewidth = 0.5, edgecolor = "black", color = None)
ax.set_title("NEX Precipitation")
plt.tight_layout()
plt.savefig('./nex_prcp.png', dpi=600)

# %% [markdown]
# ### GDD

# %%
# CMIP
fig, ax = plt.subplots(1,1, figsize = (18,10))
# divider = make_axes_locatable(ax)
# cax = divider.append_axes("right", size="5%", pad=0.1)
# pvals.query("AgVar == 'gdd'").plot(column = "pVal_CMIP", ax = ax, cax = cax, legend = True, cmap = batlow_map, vmin=0.0, vmax=1.0)
pvals.query("AgVar == 'gdd' and pVal_CMIP < 0.05").plot(color = 'darkgray', ax = ax, legend = False)
pvals.query("AgVar == 'gdd' and pVal_CMIP >= 0.05").plot(color = '#7570b3', ax = ax, legend = False)
ax.tick_params(labelbottom=False, labelleft = False)
states.geometry.boundary.plot(ax = ax, linewidth = 0.5, edgecolor = "black", color = None)
coast.geometry.boundary.plot(ax = ax, linewidth = 0.5, edgecolor = "black", color = None)
ax.set_title("CMIP GDD")
plt.tight_layout()
plt.savefig('./cmip_gdd.png', dpi=600)
# Out:
# /Users/davidlafferty/anaconda3/envs/geoP/lib/python3.7/site-packages/geopandas/plotting.py:487: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,

# %%
# NEX
fig, ax = plt.subplots(1,1, figsize = (18,10))
# divider = make_axes_locatable(ax)
# cax = divider.append_axes("right", size="5%", pad=0.1)
# pvals.query("AgVar == 'gdd'").plot(column = "pVal_NEX", ax = ax, cax = cax, legend = True, cmap = batlow_map, vmin=0.0, vmax=1.0)
pvals.query("AgVar == 'gdd' and pVal_NEX < 0.05").plot(color = 'darkgray', ax = ax, legend = False)
pvals.query("AgVar == 'gdd' and pVal_NEX >= 0.05").plot(color = '#7570b3', ax = ax, legend = False)
ax.tick_params(labelbottom=False, labelleft = False)
states.geometry.boundary.plot(ax = ax, linewidth = 0.5, edgecolor = "black", color = None)
coast.geometry.boundary.plot(ax = ax, linewidth = 0.5, edgecolor = "black", color = None)
ax.set_title("NEX GDD")
plt.tight_layout()
plt.savefig('./nex_gdd.png', dpi=600)

# %% [markdown]
# ### eGDD

# %%
# CMIP
fig, ax = plt.subplots(1,1, figsize = (18,10))
# divider = make_axes_locatable(ax)
# cax = divider.append_axes("right", size="5%", pad=0.1)
# pvals.query("AgVar == 'egdd'").plot(column = "pVal_CMIP", ax = ax, cax = cax, legend = True, cmap = batlow_map, vmin=0.0, vmax=1.0)
pvals.query("AgVar == 'egdd' and pVal_CMIP < 0.05").plot(color = 'darkgray', ax = ax, legend = False)
pvals.query("AgVar == 'egdd' and pVal_CMIP >= 0.05").plot(color = '#7570b3', ax = ax, legend = False)
ax.tick_params(labelbottom=False, labelleft = False)
states.geometry.boundary.plot(ax = ax, linewidth = 0.5, edgecolor = "black", color = None)
coast.geometry.boundary.plot(ax = ax, linewidth = 0.5, edgecolor = "black", color = None)
ax.set_title("CMIP")
plt.tight_layout()
plt.savefig('./cmip_all.png', dpi=600)
# Out:
# /Users/davidlafferty/anaconda3/envs/geoP/lib/python3.7/site-packages/geopandas/plotting.py:487: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,

# %%
# NEX
fig, ax = plt.subplots(1,1, figsize = (18,10))
# divider = make_axes_locatable(ax)
# cax = divider.append_axes("right", size="5%", pad=0.1)
# pvals.query("AgVar == 'egdd'").plot(column = "pVal_NEX", ax = ax, cax = cax, legend = True, cmap = batlow_map, vmin=0.0, vmax=1.0)
pvals.query("AgVar == 'egdd' and pVal_NEX < 0.05").plot(color = 'darkgray', ax = ax, legend = False)
pvals.query("AgVar == 'egdd' and pVal_NEX >= 0.05").plot(color = '#7570b3', ax = ax, legend = False)
ax.tick_params(labelbottom=False, labelleft = False)
states.geometry.boundary.plot(ax = ax, linewidth = 0.5, edgecolor = "black", color = None)
coast.geometry.boundary.plot(ax = ax, linewidth = 0.5, edgecolor = "black", color = None)
ax.set_title("NEX Extreme GDD")
plt.tight_layout()
plt.savefig('./nex_egdd.png', dpi=600)

# %% [markdown]
# ### Specific Example: Howard County, Iowa (19089)

# %%
# CMIP calc
cmip_ens = cmip.query("AgVar == 'egdd' and Year <= 2005 and Year >= 1956 and GEOID == '19089'").groupby(["Year"]).mean().drop(columns = ['GMFD','ensemble_mean']).T.values.reshape((21,50,1))
gmfd_obs = gmfd.query("Year <= 2005 and GEOID == '19089'")['egdd'].groupby(["Year"]).mean().values.reshape((50,1))
cmip_gdd = rankz(gmfd_obs, cmip_ens)

# NEX calc
nex_ens = nex.query("AgVar == 'egdd' and Year <= 2005 and Year >= 1956 and GEOID == '19089'").groupby(["Year"]).mean().drop(columns = ['GMFD','ensemble_mean']).T.values.reshape((21,50,1))
gmfd_obs = gmfd.query("Year <= 2005 and GEOID == '19089'")['egdd'].groupby("Year").mean().values.reshape((50,1))
nex_gdd = rankz(gmfd_obs, nex_ens)

# Plot
fig, ax = plt.subplots(2,1, figsize = (7,10), sharex = True)

ax[0].bar(range(1,cmip_ens.shape[0]+2), cmip_gdd[0])
ax[0].arrow(0., 1/22. * 50, 22.5, 0., color="gray", ls = "--")
ax[1].bar(range(1,nex_ens.shape[0]+2), nex_gdd[0])
ax[1].arrow(0., 1/22. * 50, 22.5, 0., color="gray", ls = "--")

ax[0].set_title("CMIP Extreme GDD")
ax[1].set_title("NEX Extreme GDD")

ax[0].set_xlim([0.5,22.5])

ax[1].set_xlabel("Rank")

ax[0].set_ylabel("Frequency")
ax[1].set_ylabel("Frequency")

plt.tight_layout()
# plt.savefig("./egdd_rankHist.png", dpi = 600)
plt.show()

# %%
# CMIP calc
cmip_ens = cmip.query("AgVar == 'gdd' and Year <= 2005 and Year >= 1956 and GEOID == '48073'").groupby(["Year"]).mean().drop(columns = ['GMFD','ensemble_mean']).T.values.reshape((21,50,1))
gmfd_obs = gmfd.query("Year <= 2005 and GEOID == '48073'")['gdd'].groupby(["Year"]).mean().values.reshape((50,1))
cmip_gdd = rankz(gmfd_obs, cmip_ens)

# NEX calc
nex_ens = nex.query("AgVar == 'gdd' and Year <= 2005 and Year >= 1956 and GEOID == '48073'").groupby(["Year"]).mean().drop(columns = ['GMFD','ensemble_mean']).T.values.reshape((21,50,1))
gmfd_obs = gmfd.query("Year <= 2005 and GEOID == '48073'")['gdd'].groupby("Year").mean().values.reshape((50,1))
nex_gdd = rankz(gmfd_obs, nex_ens)

# Plot
fig, ax = plt.subplots(2,1, figsize = (7,10), sharex = True)

ax[0].bar(range(1,cmip_ens.shape[0]+2), cmip_gdd[0])
ax[0].arrow(0., 1/22. * 50, 22.5, 0., color="gray", ls = "--")
ax[1].bar(range(1,nex_ens.shape[0]+2), nex_gdd[0])
ax[1].arrow(0., 1/22. * 50, 22.5, 0., color="gray", ls = "--")

ax[0].set_title("CMIP Extreme GDD")
ax[1].set_title("NEX Extreme GDD")

ax[0].set_xlim([0.5,22.5])

ax[1].set_xlabel("Rank")

ax[0].set_ylabel("Frequency")
ax[1].set_ylabel("Frequency")

plt.tight_layout()
# plt.savefig("./egdd_rankHist.png", dpi = 600)
plt.show()
